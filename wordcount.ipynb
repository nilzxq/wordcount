# %%
# -*- coding: UTF-8 -*-

# %%
import numpy as np
import pandas as pd
import jieba
import jieba.analyse
import codecs
import csv

# %%
#设置pd的显示长度
pd.set_option('max_colwidth',500)

# %%
#载入数据
rows=pd.read_csv('java_of_harbin_1.csv',header=0,encoding='utf-8',usecols=[8],dtype=str)

# %%
rows
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   职位详细要求
# 0    职位信息\n\n\n1、参与java/j2ee技术的相关产品设计、开发、测试等产品研发工作；2、参与软件工程文档、产品文档编写，满足质量要求；3、参与各省新需求分析及新需求开发。任职要求：1、国家正规院校大学本科或以上学历，计算机或相关专业毕业；2、1年以上java/j2ee开发经验，有电信行业经验开发经验者优先；3、熟悉spring，struts和hibernate等主流的开发框架，熟悉jsp/servlet/javascript等web开发技术；4、熟练掌握数据库oracle、sybase、sqlserver中至少一种，能够熟练进行编程。5、熟练使用unix、linux，能进行shell编程；6、熟悉软件技术文档的编写，具备良好的文档编制习惯和代码书写规范；7、具有强烈的工作责任心、有良好的沟通能力和团队合作精神、承压能力；8、学习能力强，拥有优秀的逻辑思维能力与自我管理能力。本职位同期在：东北区区域（哈尔滨、长春）城市招聘，如您考虑在以上城市工作，请在投递简历时标注期望的工作地点。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t...
# 1    职位信息\n\n\n1、具有多年java开发经验， 熟悉ssh ,spring，mybatis 框架及其原理2、有优秀的数据库设计和优化能力，熟练应用oracle和sql server3、熟悉相关的技术原理、规范、标准，热爱技术、具备快速学习的能力4、熟练使用html5，xml，json，css，javascript，jquery等前端技术；5、 有团队精神，有足够的沟通意识、能力，能承受一定的工作压力优先条件：1.  了解redis,memcache、mongodb 等缓存系统优先2.  有处理高并发数据经验优先3.  有高并发、大流量系统开发经验者优先。4.  1年以上多线程开发经验\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t算法工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：汉水路277号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n...
# 2    职位信息\n\n\n1、开发经验1-2年或以上，精通java语言，熟练使用编程工具jbuider或myeclipse。 2、熟悉html, css, javascript。有web前台开发经验，对javascript前台开发有深入理解。 3、熟悉j2ee相关技术，最好有用过spring、struts、hibernate、ibatis相关经验。 4、精通sql，熟悉oracle/mysql/db2关系数据库中的一种。 5、熟练使用和配置一种或一种以上的主流应用服务器（weblogic,websphere,tomcat)。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：道里区友谊路436号-龙江银行\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t信雅达系统工程股份有限公司（下称“信雅达”或“公司”）是中国较早在上海证券交易所上市（股票代码：600571）的高科技软...
# 3    职位信息\n\n\n职位要求：1.  3年以上javaee开发经验2.  熟练使用eclipse等ide工具3.  熟悉ssh ,spring，mybatis 框架及其原理，阅读过源码4.  熟练使用mysql数据库，有优秀的数据库设计和优化能力5.  熟练使用git,svn等版本管理工具6.  熟练使用linux系统，熟悉常用操作命令，能在linux环境中部署和运行程序7.  熟悉相关的技术原理、规范、标准，热爱技术、喜欢研究底层8.  有团队精神，有足够的沟通意识、能力，能承受一定的工作压力 职位描述：1.    银多网后台系统功能开发2.    银多网移动接口开发3.    数据处理中间件开发  优先条件1.  了解redis,memcache、mongodb 等缓存系统优先2.  有处理高并发数据经验优先3.  1年以上多线程开发经验4.  有基于分布式系统的java程序开发经验5.   有大数据开发经验6.  有高并发、大流量系统开发经验者优先。7.  了解国内外常用开源产品/项目,有相应工作成果\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\...
# 4    职位信息\n\n\n岗位职责：1、负责web平台开发。2、按期完成主管安排的编码任务。3、编写部署文档、设计文档、测试文档、说明文档等。任职资格：1、三年左右java开发工作经验；2、熟练使用主流开发框架；         3、熟练使用html5，xml，json，css，javascript，jquery等前端技术；4、熟练使用oracle、mysql等关系型数据库，有良好的sql语言基础；5、熟悉hadoop、hive等大数据处理技术；6、有良好的代码习惯，有一定的需求分析能力和良好的沟通能力；7、掌握版本控制软件的使用svn、git等。8、熟练linux下编程开发，并有一定相关经验。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：哈尔滨\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\...
# 5    职位信息\n\n\n岗位职责：1、主要负责java课程培训工作授课、学员辅导工作；2、根据教学安排进行项目实训；3、参与教学项目案例研发工作。任职要求：1、一年以上企业级软件开发经验；2、拥有良好java编程风格和面向对象开发思想；3、熟练使用jsp、servlet、javabean；4、熟练使用html、css、javascript、jquery进行前端开发；5、熟练使用struts2、spring、hibernate、mybatis框架进行项目开发；6、熟练使用oracle和mysql 数据库。工作地址：哈尔滨旅游职业技术学院                 双鸭山黑煤职院联系人：鲍老师   15765583962\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t互联网软件开发工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n讲师\n教师\n软件工程师\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址...
# 6    职位信息\n\n\n1、负责产品开发；2、负责指导、处理、协调和解决项目中出现的技术问题；公司背景：it日企集团开发��目：金融 �y行 保�u �c券（大手客�粝冗m��目）相关岗位要求：1. 要求本科及以上学历，计算机相关专业或者有计算机相关证书，大专要毕业10年以上。刚开始不会日语可以，但之后要学习。2. 1年以上it开发或咨询相关工作经验（编程能力强可放宽），开发语言包含： java、 sap、abap、c＃、c/c++、php、.net、cobol 、intra-mart、salesforce、ios、android、ai、、ebs、dynamics等等地 �c： 日企月 薪： 20---70万日元以上（��能力优待）20万日元相当于1.2万人民币\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t系统工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n日企\nit\n编程\n开发\njava\nphp\nabap\n工程师\n技术员\...
# 7    职位信息\n\n\n1、主要负责java相关课程培训、课程教案编写以及课件开发工作；2、根据教学安排进行备课，完善授课视频等资料，积极主动完成课程教学、辅导工作；3、带领实训学生按照项目规范项目开发流程进行项目开发任职要求： 1、具有2年或以上项目开发经验，有教学经验者优先；2、专科以上学历，热爱教育事业；3、熟悉java语言，能够使用java技术实现b/s网站制作技术；4、精通sqlserver、oracle、mysql数据库其中一个；5、熟练linux操作系统，熟练掌握linux下的开发环境；6、熟悉主流行框架技术springmvc、spring、hibernate、struts2、mybatis框架开发，并具备实际的项目开发经验；6、熟悉maven、svn、git、hadoop。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t培训讲师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t职业技术教师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\njava讲师\njava老师\n\n\n\n微信分享\n...
# 8    职位信息\n\n\r\n\t\t\t\t\t\tjava开发工程师岗位职责： 1、根据开发进度和任务分配，完成软件架构设计及编程任务； 2、进行程序单元、功能的测试，查出软件存在的缺陷并保证其质量； 3、进行编制项目文档和质量记录的工作； 4、维护软件，使之保持可用性和稳定性； 5、能独立处理和解决所负责的任务。 任职要求： 1、大专及以上学历，3年以上java软件项目开发经验； 2、精通java语言，j2ee技术知识及主流框架技术；包括：spring、hibernate、mybaits、freemarker等；3、掌握图形框架fusioncharts、jfreechart或其他框架，能基于图形框架进行二次开发；4、熟练掌握oracle、mysql数据库应用，部署、调优； 5、学习能力强，责任心强，有较强的沟通协调能力。 \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n周末双休\n带薪年假\n年终双薪\n奖金丰厚\n节日福利\n人才推荐奖\n\n\n\n微信分享\n\n\n\n\n\...
# 9    职位信息\n\n\n1、本科及以上学历，计算机相关专业2、具有扎实的java语言基础，熟悉jsp/servlet、javascript、ajax、jquery等web开发基础技术3、熟练使用spring、spring mvc、mybatis或ibatis框架4、熟练掌握db2、oracle、sqlserver等主流数据库的相关技术5、熟悉windows/linux开发环境。熟悉tomcat等服务器6、两年以上工作经验7、有springcloud、jpa、vue.js开发经验优先8、有使用idea开发经验者优先9、有activiti等工作流框架开发经验者优先早八晚五，双休，法定假日，带薪年假，免费午餐，节日福利\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n开发工程师\njava\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：哈平路132号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\...
# 10   职位信息\n\n\n岗位要求：1、本科以上学历，二年以上java开发经验；2、二年以上面向对象软件分析、设计经验；3、熟悉java及其主流设计架构、精通springmvc、ssh、webservice、xml技术、熟悉jquery、js等前台ui技术，熟悉oracle、精通sql语言，对性能调优有一定经验；4、熟悉主流项目管理工具（如project）、数据库建模工具(如powerdesigner)、设计工具（如visio）、配置工具svn等；5、有系统通讯技术，如webservices项目开发经验者优先；6、具有良好的主动沟通、表达能力及文档书写能力；7、能够承受工作压力、心思缜密、责任心强；8、具有良好的团队合作精神及独立解决问题的能力；9、有金融行业、财务软件开发经验优先考虑。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：哈尔滨市内\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\...
# 11   职位信息\n\n\n外派国企工作（外派工作地点：文昌街、和兴路附近或者国家电网嵩山路湘江路交口附近）要求本科及以上学历，专业不限，计算机相关为佳岗位职责：1、能独立处理和解决所负责的任务；2、根据开发进度和任务分配完成相应模块软件的设计、开发、编程任务；3、进行程序单元、功能的测试，查处软件存在的缺陷并保证其质量；4、维护软件保持可用性和稳定性；任职资格：1、计算机或相关专业本科学历以上，具有2年以上java开发经验，优秀者可适当放低工作年限要求2、良好的java基础，对java各种通讯方式有一定了解；3、熟悉spring开发和配置；4、熟练使用mybatis；5、熟练使用oracle、mysql数据库；6、有为手机端提供服务接口经历者优先；7、有组织协调能力者优先。工作地址：哈尔滨市南岗区嵩山路111号黑龙江科技大学创业创新基地3层基本待遇：双休+五险+法定假日+工作餐+加班补助（或调休）\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t...
# 12   职位信息\n\n\n1、 有一定工作经验，2-3年java开发或android开发。2、学历：二本以上统招全日制本科毕业生以上，计算机或相关专业优先。3、有学习能力，能够在工作中不断进取。4、善于团队配合，沟通能力强。工作内容：1、进行安卓app的开发工作。2、公司给与一定的学习时间，从java开发转android开发。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\njava\nandroid\n安卓\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：嵩山路19号腾讯众创空间6楼\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t公司哈尔滨立成通信软件开发有限公司，是成立于2005年的软件开发企业。公司专注于电信级运营平台开发、数字娱乐平台、企业级网络解决方案、企业网上办公(oa)系统开发等。公司拥有成熟的盈利模式与广阔的发展前景。我们的理想：成为中国一流的软件开发与服务公司，为客户提供卓越...
# 13   职位信息\n\n\n岗位职责：1、热爱软件开发工作；2、学习能力强，自我提高能力强；3、配合项目经理完成相关任务目标；4、具有很强的学习和独立分析能力、工作责任心、良好的沟通能力和团体合作精神。岗位要求：1、工作认真、细致、敬业，责任心强 ；2、有良好的沟通能力和表达能力；3、有无经验均可。工作时间：早9-晚5 双休 法定假日休息公司福利：公司缴纳基本的五险一金，带薪年假，定期公司体检，每年一次员工旅游\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区文景街100号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t中软国际信息技术有限公司（以下简称：中软国际）是中国领先的大型综合性软件与信息服务企业，成立于2000年，为香港主板上市公司，股票代码354。 面对当今互联网化，以及云计算、大数据的挑战，中软国际建立了线下与线上互动的业务结构（o2o）。 线下业务...
# 14   职位信息\n\n\n一、岗位描述：1、参与软件工程系统的设计、开发、测试等过程，并协助工程师或项目经理完成软件研发等相关工作；2、根据公司技术文档要求编写相应技术文档；3、协调各个程序员的工作，并能与其它软件工程师协作工作；二、任职资格：1、全日制统招2018届大专及以上应届生，自动化、计算机、通信工程、电子信息、机电等相关专业；2、良好的专业理论基础知识并了解软硬件开发的流程；3、良好的学习能力，科技一直在发展，只有不断的学习才能保证能跟上时代的脚步；三、福利待遇：1、五险一金，商业意外险，享受双休等福利，集体活动或旅游等；2、全体员工除享受以上福利待遇外还将享受带薪年假、病假、婚假、丧假、产假等国家法定节假日；3、有良好的晋升渠道：实习生--初级软件工程师--中级软件工程师--高级软件工程师--项目主管--项目经理；四、工作时间周一至周五，早上9：00-下午18:00，周末双休；\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\...
# 15   职位信息\n\n\n1、根据开发进度和任务分配，完成软件架构设计及编程任务；2、进行程序单元、功能的测试，查出软件存在的缺陷并保证其质量；3、进行编制项目文档和质量记录的工作；4、维护软件，使之保持可用性和稳定性；5、能独立处理和解决所负责的任务。任职要求：1、大专及以上学历，2年以上java软件项目开发经验；2、精通java语言，j2ee技术知识及主流框架技术；包括：spring、hibernate、mybaits、freemarker等；3、掌握图形框架fusioncharts、jfreechart或其他框架，能基于图形框架进行二次开发；4、熟练掌握oracle、mysql数据库应用，部署、调优；5、学习能力强，责任心强，有较强的沟通协调能力。公司官网  电脑端网址：http://www.hljlida.com/，手机端网址：www.hljlida.com/wap\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\njava后台开发\n\n\n\n微信分享\n\n\n\n\n\n\n\...
# 16   职位信息\n\n\n技能要求： 1.1年以上java开发经验； 2.熟悉spring，struts和hibernate等主流的开发框架； 3.熟悉tomcat服务器使用部署； 4.熟悉数据库mysql、oracle中至少一种，能够熟练进行编程；    5.熟悉技术文档的编写，具备良好的文档编制能力和代码书写规范。 6.具有强烈的工作责任心、有良好的沟通能力和团队合作精神、承压能力，能够独立完成项目开发； 主要工作职责： 1、承担生产系统的部分设计工作； 3、承担生产系统的开发工作，对代码质量及进度负责； 3、负责现有系统的优化以及维护工作； 4、负责撰写项目相关的各类技术文档薪资及福利待遇1、薪酬：根据开发能力判定。2、保险福利：（1）缴纳养老保险、医疗、工伤、生育、失业保险。（2）补充商业保险，享受更多的医疗保障，门诊医疗也可报销。 3、培训福利：员工可享受免费专业的入职培训、业务培训、进阶培训、管理培训等。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t其他\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n技术、工程师\n\n\n\n微信...
# 17   职位信息\n\n\n岗位职责：1、根据设计文档、进度安排和编码规范实现软件开发，对平台的其他模块进行代码审核；2、参与系统的概要设计，参与设计文档的编写；3、参与相关模块的设计文档审核及评审；4、参与集成测试方案、集成测试用例的设计和实现，对负责的模块软件进行单元测试，并修改测试中发现的bug；5、对客户进行技术支持，及时有效解决客户问题，为客户的具体应用提供相应的建议；6、参与产品/项目的需求分析、需求评审，收集市场、客户需求，为产品的总体规划提供资料。任职要求：1、全日制本科级以上学历，计算机相关专业；2、具备3年及以上软件开发相关经验；3、精通springboot、springcloud、hibernate、springmvc等技术；4、熟悉关系数据库系统oracle，mysql，postgresql；5、具备编写需求、设计、使用说明等常见软件工程文档能力；6、具备良好的沟通表达能力、责任心和团队协作能力，能接受出差。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n...
# 18   职位信息\n\n\n1、了解产品需求或业务方案，辅助完成系统功能定义，程序设计；2、根据业务需要，完成公司产品代码编写、调试、测试和维护；3、分析并解决软件开发过程中的问题；4、配合项目经理、产品经理完成相关任务目标；5、参与部门间技术沟通交流，并提供必要的技术支持服务；6、参与编制项目的运维文档、项目文档、开发文档。任职要求：1、计算机相关专业专科及以上学历，2年以上工作经验；2、精通j2ee相关技术，扎实的java基础，熟悉spring mvc框架，熟练使用spring、struts2、mybatis等开源框架；3、具备使用javascript、jquery、html、divcss,angularjs等基本页面开发能力；4、至少掌握mysql，oracle，sql server等主流数据库中的一种，有一定数据库设计能力，有实际sql性能调优经验；5、有良好的需求分析和沟通能力；6、从事过大数据分析相关工作者优先；7、从事过网络安全、系统安全相关产品开发者优先。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t...
# 19   职位信息\n\n\n1、参与系统需求分析、设计，以及相关文档编写等工作。2、完成软件系统代码的实现，编写代码注释和相关开发文档。 3、根据设计文档或需求说明完成代码编写，调试，测试和维护。 4、分析并解决软件开发以及实际运行过程中的问题。 5、配合团队成员完成公司指派的其他相关任务。任职要求专业知识：1、软件相关专业专科以上学历，2年以上软件开发工作经验。 2、熟练掌握java开发语言编程。 3、熟练运用  myeclipse、svn、tomcat开发工具；4、有主流数据库sql server 或 oracle 或 mysql 应用开发经验，可熟练编写存储过程、对数据调优、有较强的设计能力等；5、拥有良好的编码习惯、良好的逻辑思维能力、分析与定位问题的能力、强烈的责任心、能适应高强度工作。6、具备良好的沟通交流能力、团队合作精神。7、有微信端、小程序、app开发经验者优先考虑8、具备尖端技术研究攻关者优先考虑工作经验：1、软件相关专业专科以上学历，2年以上软件开发工作经验。 \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t互联网软件开发工程师\t\t\...
# 20   职位信息\n\n\n1. 统招本科及以上学历，3年以上java编程经验，负责公司自营产品研发。2. 责任心强、思维敏捷、良好编码习惯、良好的逻辑思维能力/沟通能力、分析与定位问题的能力，能适应公司相关安排工作。3. 精通spring boot（ssm/ssh）spring，spring mvc，mybatis，dubbo，zoopeeker，kafka等相关技术，4. 精通sql 语句以及no sql数据库（如redis）,精通js,精通html5相关技术5. 精通至少一种网络协议并有对应开发经验（http、tcp、udp等）6. 精通主流数据库mysql、sql server、oracle其中一种7. 有app服务端实际开发经验，熟悉linux，nginx、tomcat部署及性能调优，解决高并发等问题。8. 精通使用第三方开源库，并可以进行项目需求，进行修改适用。9. 精通面向对象的程序设计思想和设计模式，熟练理解mvc以及mvvm10. 熟练书写需求文档、软件设计文档、开发文档、软件说明书等常用软件行业文档。11. 有成熟项目经验，cet4或以上，技术博客，熟悉多种编程语言...
# 21   职位信息\n\n\n1.熟练掌握java技术、（ssm）spring，spring mvc，mybatis，spring boot、ssh等相关技术。 2.了解web开发，jquery、javascript、ajax、dom、html/html5/xml、css/css3等前端开发技术等前端技术；3.熟练掌握关系型数据库（如oracle、mysql），有非关系数据库经验者优先(如es、hbase)；4.掌握报表开发（如finereport）；5.了解并掌握etl，掌握kettle使用；6.掌握基本的linux操作；7.有大数据开发经验者优先；8.具有良好的表达、沟通、学习及问题分析能力；9.有独立完成项目的能力；                                    10.沟通能力强，具有良好的团队合作意识 。 \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n...
# 22   职位信息\n\n\n注：此工作职位工作地为日本东京。    公司免费负责日本工作前的指导与咨询，包括日本职场人际关系、工作技术指导、日语的提高、职场礼仪等。咨询微信：dlzhuyijiaoyu1、专科以上学历，计算机相关专业或日语专业；2、日语n2以上水平（技术强者日语可以弱化）；3、开发语言:java、 c＃、c/c++、cobol、 .net、intra-mart、vb、大数据等；4、有对日开发经验者优先；5、工作地：东京圈；6、有加班费，交通费全额报销，各种福利待遇齐全，每年涨薪1-2次；7、薪资：25万~70万日元/月，根据日语能力技术经验等综合判断；8、免费提供赴日前指导与咨询；9、初次到日本的员工可预支10万日元安家费；10、公司负责办理签证报销相关费用；\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n软件工程师\njava\nc\n.net\n对日\n日语\n软件开发\...
# 23   职位信息\n\n\n一. 角色定义1. 精通软件开发基础知识和技能，能够独立完成多个模块的设计、编码、测试等工作，有效指导中级软件人员完成软件开发工作，能够对重大技术难题进行分析解决，根据需要对系统进行优化，提高系统性能。2. 协助项目经理分析需求，形成需求说明书，能够带领团队，按计划完成模块或系统的开发。3. 完成代码编写工作，配合测试人员完成系统测试及改进工作，组织编写项目各种文档。二. 工作经验1. 从事软件编程相关工作经验，本科3年以上，研究生2年以上；2. 有大型企业级系统开发经验；3. 参与过10人以上团队至少完成过5个项目；4. 具备通信及车联网行业相关背景优先三. 学历1. 计算机或通信相关专业本科毕业以上；四. 必备知识1、负责相关产品的前端交互设计、开发，提升用户体验，了解产品开发规范。2、根据设计稿，实现html和页面效果。任职要求：1、3年以上web开发经验，了解w3c相关标准，有大型门户网站或成熟产品开发经验者优先。2、熟悉web开发，html/html5/xml，css/css3等前端开发技术；了解ajax、dom等前端技术。3、熟悉使用jquery...
# 24   职位信息\n\n\n学历要求：本科以上(含)，计算机、软件、通信、电子或相关专业；岗位职责：1、软件的程序设计与代码编写；2、有关技术方案、文档的编写，软件单元的测试；3、根据项目具体要求，承担开发任务，按计划完成任务目标；4、配合系统分析人员完成软件系统以及模块的需求调研、需求分析；5、独立完成软件系统及模块的编码；6、协助测试人员完成软件系统及模块的测试；7、负责编制与项目相关的技术文档。任职要求: 1、 精通java语言，具有在j2ee标准下从事b/s项目开发的具体经验；2、 熟练掌握spring、spring mvc、spring jdbc，熟悉struts2、hibernate等常用开发框架；3、 熟练掌握jsp、html、jquery、css、xml，熟悉http/https、socket等技术；4、 熟练掌握mysql、oracle，sql server，db2中至少一种的数据库开发和管理技术；5、 熟练掌握tomcat、websphere、weblogic、jboss 中至少一种的服务器组件开发技术；    6、 熟练使用eclipse、svn/cvs，掌握gi...
# 25   职位信息\n\n\n1、熟练使用java语言，有一年以上相关工作经验者优先；2、 熟练掌握基于web的应用程序开发；3、 熟练掌握jsp、xml、javascript、webservice，ajax，jquery，springmvc，mybatis，spring boot（ssm/ssh）spring，；4、 有使用nginx  dubbo   zookeeper  bootstrap requirejs redis   angularjs  前后端分离模 的相关经验，熟悉相关开发模式，有一定的开发能力；5、 强烈的责任心和团队精神，良好的沟通表达能力、文档编写能力；6、熟练使用ssh；7、精通主流数据库mysql、sql server、oracle其中一种8、精通使用第三方开源库，并可以进行项目需求，进行修改适用。9、精通面向对象的程序设计思想和设计模式，熟练理解mvc以及mvvm10、 熟练书写需求文档、软件设计文档、开发文档、软件说明书等常用软件行业文档。11、有成熟项目经验\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t其他\t\t\t\t\t...
# 26   职位信息\n\n\n  岗位职责：  一、3年以上某种语言（java、c#、.net）开发经验。 二、3年以上某种数据库（oracle、sql server等）的使用经验。 三、日语2级以上，或能达到能与日方直接交流（面试时均是和日方直接沟通） 四、能团结同事，能虚心接受同事建议，能适合团队开发。 五、统招本科毕业，有学位证。      \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n长期出差日本\n日语\njava\nc#\n.net\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：软件园8号楼\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t企业概要企业名称 大连艾林克斯科技有限公司  (dalian i-links technology  corporation)电话 137-9516-2103　（日语）     139-4209-7054　（汉语）邮件 dalian@i-link...
# 27   职位信息\n\n\n岗位职责：1.参与公司产品项目上的二次开发工作；2.负责技术支持工作；3.负责客户二次开发需求分析工作。职位要求：1.计算机或者计算机相关专业。2.良好的问题理解能力，能够理解以及处理复杂逻辑。3.1年以上的java开发经验优先录用，精通java,jsp,serverlet编程,熟练掌握javascript、ajax。4.掌握j2ee的相关知识，有相关经验者优先.5.掌握数据库的相关知识，熟悉sqlserver及oracle。6.良好的自学能力，团队精神以及适合在高压力环境下工作。7.具有一定的文档编写能力。8. 熟悉linux操作系统（windows,linux等）9.熟悉resin,tomcat等中间件的使用10.从事过oa软件开发的优先。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n双休\n五险一金\n法定节假日\n定期体检\n年中奖金\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：红旗大街180号（红旗大街与湘江...
# 28   职位信息\n\n\n1、根据公司业务发展要求进行系统需求分析，并根据市场变化调整需求设计。2、协助需求分析师将完成的项目模块给客户做演示，并收集对完成模块的意见。3、制订架构设计规范和相关的技术接口规范，丰富及提升内部开发框架功能和易用性。4、审核和评估相关方案与设计，以确保其符合架构规划，满足业务需求5、导开发人员基于框架进行开发，协助解决日常开发中碰到的框架使用问题。6、为系统应用设计、开发、风险等进行技术风险评估并提供解决方案。7、负责项目初期的技术选型，预估技术风险，评测性能指标。8、协助项目经理制定项目计划，并执行系统开发管理，包括开发计划制定、人员分配安排、进度跟踪及风险控制、测试及开发质量管理。岗位要求：1、985或211计算机相关专业本科以上学历2、4年以上软件开发或架构或管理的工作经验，2年以上架构师或相关岗位的工作经验，有大型软件架构设计经验和项目管理经验。3、熟悉http通信原理和html代码编写，掌握web services编程等。4、扎实的java基础和c#基础，熟悉io、多线程、集合等基础框架，对jvm原理有深入了解,精通各种java ee技术，包括...
# 29   职位信息\n\n\n岗位职责：1、参与java技术的相关产品设计、开发、测试等产品研发工作；2、参与软件工程文档、产品文档编写，满足质量要求；3、参与研发产品在工程项目中的安装、调试、客户化修改、开发；4、参与项目的实施及日常需求开发工作。任职要求：1、熟悉spring，struts等主流的开发框架，熟悉jsp/servlet/javascript等web开发技术。2、3年以上java开发经验。3、熟练掌握webservice开发。4、熟练掌握数据库oracle、mysql等。5、熟练使用至少一种主流j2ee应用服务器（websphere/weblogic/jboss/tomcat）。6、熟悉软件技术文档的编写，具备良好的文档编制习惯和代码书写规范。8、具有强烈的工作责任心、有良好的沟通能力和团队合作精神、承压能力。 9、学习能力强，拥有优秀的逻辑思维能力与自我管理能力。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t算法工程师\t\t\t\t\t\t\t...
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 253  职位信息\n\n\n工作职责：1、负责android手机应用软件的需求分析、功能设计、编码和测试；2、能独立进行应用程序的开发和移植，按照项目计划，按时提交高质量代码，完成开发任务。3、负责公司android平台应用的开发和维护4、配合后台和数据业务需求完成开发工作5、对android应用做出系统和数据优化任职要求：1、2年以上android客户端开发经验；2、精通android系统架构及相关技术，熟悉安卓ui框架，熟悉所有常用安卓控件；3、熟悉无线网络应用开发，精通socket和http网络接口编程, 熟悉android app客户端/服务端通讯方案；4、具有独立android客户端开发能力，熟练掌握java、设计模式、数据结构和算法；5、具有强烈的责任心和团队合作精神,喜欢创新,适应创业团队氛围；6、有主流应用软件开发经历的优先考虑；\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：金瑞林城\t\t\t\t\t\t\...
# 254  职位信息\n\n\n岗位内容：1、android系统移植及驱动开发；2、android framework定制；3、android系统camera、video、audio组件调优；4、modem模块调优；5、参与智能终端产品的系统分析，技术选型，模块编码和单元测试。岗位要求：1、3年以上android开发经验；2、掌握嵌入式linux内核裁剪移植；3、熟练掌握android hal和framework开发，具备2年以上的相关开发经验；4、精通java、c/c++语言，有面向对像的设计理念；5、熟悉android camera及多媒体子系统原理及定制经验者优先；6、对新技术有钻研精神，良好的沟通能力及团队合作精神。福利待遇：哈市行业内中高薪酬，每年1-2次调薪机会。1、五险一金+具有竞争力的薪酬体系；2、季度奖金+年终奖金；3、年假+调休假（全年9天）+年度旅游+年度体检；4、节假日慰问及员工生日慰问；5、固定工时制（五天八小时）；6、免费通勤班车（10条线路覆盖哈市各区）；7、5a级办公环境，内设餐厅、健身房、私家车停车场、各项体育球类场地；8、12个文体协会，活动多样，加速员...
# 255  职位信息\n\n\n岗位内容：1、负责android视频业务开发；2、负责视频编解码质量优化，码率、分辨率、动态效果调优；水印、滤镜开发，视频码流传输；3、负责android framework(native, framework)层软件设计，开发，移植及调试工作；4、负责android hardware层核心组件的维护优化 ，并进行模块的设计和开发；5、参与产品的系统分析，架构设计，模块编码和单元测试。岗位要求：1、全日制本科及以上学历，3年以上android开发经验；2、具有2年以上android framework框架层video、audio、camera的开发经验；3、精通 java、c/c++语言，有面向对像的设计理念；4、熟悉android framework架构，熟悉android系统service，binder等组件原理机制；5、熟悉常用音视频编解码、封装、传输、存储技术优先；熟悉ffmpeg开发优先；6、熟悉android video子系统框架，有相关开发经验优先；7、有opengl es或opencv开发经验者优先；8、具有强烈的责任心，良好的沟通能力及团队...
# 256  职位信息\n\n\n岗位职责：1. 负责在线，电话，上门咨询，耐心细致为学员服务2. 负责学员的试听预约与跟单报名，挖掘客户的潜在需求3. 负责意向学员信息的搜集和整理，确保每天有计划的回访4. 负责完成每月的招生指标，针对不同类型客户设计营销方案5. 熟练掌握公司各学科产品常见问题、师资、就业等相关信息6. 完成领导交办的其他工作任职要求：1. 有电话销售或客服工作经验者优先2. 普通话标准，形象气质好，具有较强的语言表达能力与亲和力，善于与人沟通3. 具备高度的工作热情，有耐心和爱心，人品端正，有责任感及良好的团队合作意识4. 能适应倒班制工作时间福利和待遇：1、薪资2500-3500+交通补助+话费补助+餐补+电脑补助+绩效+奖金；2、五险一金、定期旅游、节日金、生日聚会等；3、公司不定期为员工提供各种活动；4、每年免费体检一次；5、免费入职培训。传智播客成立于2006年5月，是一家专注于it培训的职业教育集团，企业现有员工1000余人。传智播客肩负着“为莘莘学子改变命运而讲课，为千万学生少走弯路而著书”的办学使命，现已向社会输送软件人才10万余人，出版书籍30多本，自主...
# 257  职位信息\n\n\n岗位职责：1.负责公司软件产品的部署、调测、维护等支持工作;2.负责维护、更新、编写软件产品的技术支持手册、系统部署文档;任职要求：1、本科及以上学历；2、具有3年大并发高可用性大型软件项目的管理实施经验;3、熟练掌握vmvare等虚拟化应用。4、熟练掌握linux/windows 主流操作系统的应用与配置,同时具备较强的操作系统日志分析问题与解决能力;5、熟练掌握java中间件(tomcat、weblogic、websphere)任意一种;6、熟练掌握ngix的配置和调优。7、熟练掌握redis的配置和使用8、熟练掌握oracle rac的安装部署和调优。9、具备良好的沟通能力,能与各层面人员沟通;优秀的协调能力强,能有效协调各种资源;具备团队合作意识,能够主动总结和分享自己的工作经验。10、熟悉java编程、hadoop大数据技术优先优先。 \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\njava中间件\nvmvare\n配置\n安装部署\n\n\n\n微信分...
# 258  职位信息\n\n\r\n\t\t\t\t\t\t1.质量管理过程推广、实施及过程支持；2. 负责项目生命周期的过程指导、跟踪、监督和检查，参与内部审核；3. 跟踪项目缺陷和重大问题并指导项目完成缺陷预防及过程控制分析；4.能对质量管理过程数据进行量化分析，确定风险，组织相关人员制定风险控制措施并确保措施得到落实；5.定期进行质量状况总结，对审计问题提出过程改进建议，推动并跟踪过程改进结果；6. 配合公司完成其他质量管理工作；任职条件：1.具有1年以上java软件开发工作经验；2. 工作主动性强，具备较强的组织协调、沟通能力，及较强的解决问题能力；3. 对项目过程跟踪和质量考核有系统的方法和实战经验；4. 能承担一定工作压力，工作认真细致、敢于创新，肯吃苦，有良好的协作和服务奉献精神；\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t质量管理/测试工程师(qa/qc工程师)\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\...
# 259  职位信息\n\n\n1、熟练掌握c#或java开发语言，有b/s架构系统开发经验。2、熟练掌握html5开发，有微信公众帐号、微信小程序开发经验。3、熟练掌握oracle、sqlserver等关系型数据库。4、有医疗卫生、社会保障等行业开发经验。待遇：薪酬面谈，提供五险一金 提供免费早餐和午餐，提供篮球、乒乓球、台球活动场地招聘邮箱：liandezp@163.com 招聘电话：0451-82322242，0451-82322240-8288\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区鸿翔路7号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t哈尔滨联德信息技术有限公司（以下简称“联德公司”）成立于1996年，是国内领先的医疗卫生、社会保障领域应用软件和全面解决方案的供应商。系双软认证企业，系国家认定的高新技术企业，通过了iso9001质量管理体系认证，...
# 260  职位信息\n\n\n1.       具有1年以上html5开发安卓、苹果等混合模式app开发经验。2.       具有2年以上java或.net开发b/s业务系统的开发经验。3.       掌握java、.net等开发语言，oracle、sqlserver等关系型数据库。4.       具有医疗行业互联网+相关项目经验者优先。5.       具有数据采集、交换和系统对接经验者优先。待遇：薪酬面谈，提供五险一金 提供免费早餐和午餐，提供篮球、乒乓球、台球活动场地招聘邮箱：liandezp@163.com 招聘电话：0451-82322242，0451-82322240-8288工作地址南岗区鸿翔路7号\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t互联网软件开发工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区鸿翔路7号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t哈尔滨联德信息技术有限公司（以下...
# 261  职位信息\n\n\n1、熟练掌握c#或java开发语言，有b/s架构系统开发经验。2、熟练掌握html5开发，有微信公众帐号、微信小程序开发经验。3、熟练掌握oracle、sqlserver等关系型数据库。4、有医疗卫生、社会保障等行业开发经验。待遇：薪酬面谈，提供五险一金 提供免费早餐和午餐，提供篮球、乒乓球、台球活动场地招聘邮箱：liandezp@163.com 招聘电话：0451-82322242，0451-82322240-8288\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区鸿翔路7号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t哈尔滨联德信息技术有限公司（以下简称“联德公司”）成立于1996年，是国内领先的医疗卫生、社会保障领域应用软件和全面解决方案的供应商。系双软认证企业，系国家认定的高新技术企业，通过了iso9001质量管理体系认证，...
# 262  职位信息\n\n\n任职要求：1.计算机相关专业，熟练掌握java、c#、.net等开发语言及其框架，数量掌握oracle、sqlserver等大型关系型数据库，具有1年以上大数据项目开发经验。2.具有分布式系统设计开发和部署经验。3.熟悉数据模型、数据处理和etl开发，熟练掌握etl相关工具。4.具有医疗区域卫生平台开发项目经验，具有同医院、医保、健康档案、电子病历等系统对接经验。5.有较强的书面与口头沟通表达能力，独立分析、解决问题的能力。待遇：薪酬面谈，提供五险一金 提供免费早餐和午餐，提供篮球、乒乓球、台球活动场地招聘邮箱：liandezp@163.com 招聘电话：0451-82322242，0451-82322240-8288\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区鸿翔路7号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t哈尔滨联...
# 263  职位信息\n\n\n  岗位职责：     1. ngs，snp，mrna，amino acid seq, genome 数据，分子育种和常规育种实验数据分析管理。  ncbi等公共数据的定期更新及维护。内部sequence数据，统计数据，实验数据的整合。对基因编辑及大规模转化技术进行信息支持。blast server和dataset 的维护，primer3，mflod，emboss，jbrowser，bowtie2，tophat，bwa，samtools，blast, gmap，galaxy, gatk 等工具的安装维护。参与生物信息及分子辅助育种的相关软件的研发。             任职要求： ？学历/学位：博士/硕士/本科 ？专业: 生物信息学，计算生物学，统计学，植物遗传育种，计算机软件工程等专业   具有相关生物信息学的基础知识和3年以上生物信息数据分析的相关工作经历熟练掌握linux系统。能够熟练使用至少一套shell系统熟练运用分析软件，如bowtie2，tophat，bwa，samtools，blast, gmap，galaxy, gatk等能够管理和分析...
# 264  职位信息\n\n\n  岗位职责：  独立领导生物信息数据分析团队完成基因组数据，序列数据，常规育种和分子育种的数据分析。  负责企业内部及外部的数据迁移，数据更新，数据清洗，数据备份，数据整合，和数据应用。  领导团队整合各种实验数据，其中包括ngs，snp，转录组，蛋白序列,基因组，常规育种，分子育种和统计数据。  领导工程师构建分析pipeline，标记生成pipeline，统计pipeline，以及实验室提出的各种需求。对大规模的基因编辑，转基因技术，基因转化技术进行信息支持与数据管理。对各种生物信息工具进行安装维护和管理。配合研发团队完成生物信息，常规育种，分子辅助育种等相关软件的研发，扩展，及维护。           职位要求：  ？学历/学位：博士/硕士 ？专业: 生物信息学，计算生物学，统计学，植物遗传育种，计算机软件工程等专业    具有极强的领导能力，团队沟通能力，自学能力和独立工作能力。能熟练处理基因芯片数据、ngs数据、高通量基因检测数据，以及其他实验数据。指导团队，掌握分析软件，如bowtie2，tophat，bwa，samtools，blast, ...
# 265  职位信息\n\n\n  计算机、软件开发等相关专业（2人）  （1）3年以上软件开发经验、熟练掌握.net /ef/java/linq/js/android等一种或多种开发语言及框架。  （2）熟练使用sqlserver、oracl、sqllite等相关数据库、并具有数据库调优经验、了解索引、视图、存储过程等相关机制。  （3）熟悉web services、webapi等相关机制。  （4）熟悉软件开发流程，思路清晰、代码规范。  （5）具备优秀的团队合作意识、组织能力和良好的精神状态，工作效率高。  \n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t计算机辅助设计工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：宾西技术开发区强宾路\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t北大荒垦丰种业股份有限公司是集研发、生...
# 266  职位信息\n\n\n职位描述：1. 利用html/css/javascript等各种web技术进行界面开发；2. 参与前端架构和模块设计以及文档编写；3. 进行丰富互联网体验的web开发，致力于通过技术改善用户体验；4. 与企业客户�鹬窒低扯越拥魇浴�任职条件：1、 熟练掌握web前端开发技术，包括：html、css、javascript，能够深刻理解表现与行为的分离、w3c标准；2、熟悉常用框架如node.js、angularjs、vue等其中的一种；3、熟练使用jquery，可以熟练使用jqueryf开发前端组件，能够基于jquery�苑�ui组件；4、能够熟练运用前端技术处理多浏览器兼容，能够熟练使用浏览器调试工具；需要具有web前端性能优化经猃;熟悉hthl5和css3，至少了解一种（如：php、jsp、java、node.js)后台开发语言经验；\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\tweb前端开发\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：南岗区\t\...
# 267  职位信息\n\n\n招聘要求：（1）具有完整的移动端项目经验2年以上，包括ios和android。（2）至少在2个项目中承担过项目经理职责。（3）能够熟练掌握iconic框架开发或者移动原生开发技术（android、ios）。（4）具有两年以上移动端开发的工作经验。（5）具有政府项目成功案例优先考虑。（6）具有java web开发经验优先考虑。岗位职责：（1）能够承当项目经理职责（2）能够熟练掌握移动端开发技术，并指导技术人员（3）能够熟练掌握iconic框架开发或者移动原生开发技术（android、ios）\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t手机应用开发工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：香坊区松花路9号中国云谷a8栋3层\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t 黑龙江海康软件工程有限公司成立于1997年，隶属于中国网通黑龙江实业公司。总部设在哈尔滨，北京、上海设有分公司，并在...
# 268  职位信息\n\n\n1、负责基于android系统平台上开发app；2、根据产品需求和设计文档完成架构和模块的设计、编码和单元测试工作；3、本科以上，具备2年以上工作经验，1年以上android开发经验；4、扎实的java基础，熟悉基本数据结构和算法，特别有多线程开发经验；5、了解html5、css3，js和跨平台开发，比如，hybird app开发模式，熟悉github使用，了解主流的开源框架；6、较强的责任心，沟通表达流畅，具有团队合作精神；7、有app优化经验，如网络请求，内存优化，动态和加载等方面和android多版本多机型适配经验者优先。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：文昌街238号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t 黑龙江海康软件工程有限公司成立于1997年，隶属于中国网通黑龙江实业公司。总部设在哈尔滨，北京、上海设有...
# 269  职位信息\n\n\n任职要求：1、1-2年及以上pc web前端开发和脚本开发经验经验；2、精通javascript、ajax等web技术，熟悉jquery/bootstrap优先；3、熟练使用html5/css3、html/xhtml、css等网页制作技术，熟悉页面架构和布局；4、有较强的自学能力，能够快速解决各种常用浏览器（ie，firefox，chrome，safari等）的兼容问题，熟悉响应式网页设计；5、有良好的文档书写及编码习惯，良好的团队工作和时间管理；够处理售后问题,能够熟练掌握java web技术,能够与客户进行沟通交流。6、热爱前端，具有良好的团队合作精神，善于沟通交流；富有责任心，热情，积极向上；有较强的沟通能力，吃苦耐劳，能在较大的压力下保持良好的工作状态。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：香坊区松花路9号中国云谷a8栋3层\t\t\t\t\t\t\t\n地图\n\n\n\n\n\...
# 270  职位信息\n\n\n1.要求有过代码开发经验，沟通和理解能力好；2.熟悉各类操作系统及数据库的安装、实施、部署；3.计算机相关专业，大专以上学历，有同岗经验者优先。要求具有良好的沟通能力，能长期出差，对业务理解能力强，能独立部署项目者优先有意者请将简历+身份证扫描件+毕业证扫描件发送至公司邮箱hr87960700@126.com，符合要求者公司将统一安排面试。联系电话：0451-87960700-8024  公司主页：http://www.highcom.com.cn\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t技术支持/维护工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n实施\n运维\n技术支持\njava\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：香坊区松花路9号中国云谷a8栋3层\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t 黑龙江海康软件工程有限公司成立于1997年，隶属于中国网通黑龙江实业公司。总部设在哈尔滨，北京、...
# 271  职位信息\n\n\n岗位职责： 1、负责完成集成软件的现场部署工作； 2、负责完成集成软件的现场维护工作； 3、能够很好的向研发人员描述清楚问题； 4、负责软件变更说明、功能特性等各类技术文档的编写工作。 任职资格： 1、学历：本科，计算机、通信、自动化相关专业，gis专业优先； 2、熟练掌握windows系列操作系统，了解linux操作系统； 3、了解.net,java开发平台；了解c++、c#、java开发语言； 4、对oracle、sqlserver、mysql等数据库有一定的了解；熟练使用基本的sql语句； 5、具有较强的学习能力、踏实的工作态度和很强的责任心，具有良好的沟通能力和团队合作精神；能够吃苦耐劳，适应经常出差； 6、需能适应出差,； 7、工作地点：哈尔滨待遇及福利： 待遇： 4000-6000福利： 五险一金、周末双休、法定节假日正常放假 职业发展空间： 项目实施工程师―> 项目经理―> 售前经理\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t项目执行/协调人员\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t...
# 272  职位信息\n\n\n工作环境好，假期多，薪资上不封顶\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t职业技术教师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\njava及vr教学\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：智谷一街5018号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t我公司上层企业哈尔滨市艾特职业培训学校、与各大企事业单位形成订单式培养模式， 艾特国际职业学校是新加坡艾特教育集团中国全资学校，在航空领城与国际航空公司,如新加坡航空公司，国内航空公司，如南方航空，，深圳东海，形诚订单培养及招聘基地。也在2008年与国际知名品牌lv公司进行中国区招聘活动，并输送了近百名学生就业在集团公司，2009年也曾与新加坡樟宜机场进行联合人员选拔，近百名学生前往新加坡机场地勤工作。2010年我们与世界500强众多企业签署定向培养协议如:电子巨头苹果公司，诺基亚公司，国内阿里巴巴公司，华为集团等公司。在黑龙江省内，与黑龙江电视台《勇往...
# 273  职位信息\n\n\n大数据软件开发工程师【工作职责】1、参与大数据业务平台系统架构分析与设计；2、负责大数据业务平台核心模块方案设计与开发；3、负责系统的持续集成与自动化部署；4、负责系统上线后的问题定位与故障修复。【岗位要求】1、大学本科及以上学历，通信、计算机、应用数学等相关专业毕业；2、3年以上java或scala开发经验，熟悉多线程、网络通信和数据库编程；3、熟悉mpp数据库的运行机制和体系架构，精通数据库sql性能调优者优先；4、熟悉hadoop/spark/hive/kafka大数据平台和核心功能组件，有相关组件开发和性能优化经验者优先；5、熟悉linux操作系统，熟练运用shell/python脚本。简历投递：10135669@zte.com.cn联系电话：17352878250 谭\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t高级软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n大数据，ai\n\n\n\n微信分享\n...
# 274  职位信息\n\n\n工作职责：1、负责基于android系统手机应用的开发、需求沟通，设计、功能模块实现、功能测试与维护;2、负责技术框架研究，团队技术难点的解决。任职要求：1、本科及以上学历，计算机相关专业;3年以上工作经验；2、精通java，具备扎实的编程基础和良好的编程习惯;3、熟悉android系统，能根据产品设计和要求独立完成开发任务;4、具备良好的沟通能力、团队合作精神。工作认真负责、具有高度责任感、优秀的自学能力。有较强的独立意识和解决问题能力。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t手机应用开发工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：哈尔滨\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t        北京致远互联软件股份有限公司（beijing seeyon internet so...
# 275  职位信息\n\n\r\n\t\t\t\t\t\t职位要求1 计算机及相关专业专科及以上学历，至少2年以上软件测试工作经验2 有产品意识，熟悉web和app测试流程和测试方法，熟悉测试理论，高效设计测试用例3 能够独立部署实际生产环境,并跟踪其使用情况反馈；能够改进测试过程，改进测试技术，形成测试体系4 思维敏捷，工作积极主动，具备快速的学习能力，具备良好的沟通能力，具有强烈的事业心和责任感职位描述：1、负责移动app功能测试工作，能够独立制定测试计划，设计测试用例；2、负责测试用例设计、执行，对缺陷进行跟踪，推动问题及时解决；3、与项目团队成员进行有效沟通，积极推动问题处理并及时解决。优先条件：1 熟悉android或ios系统，有编程语言基础，java、python开发经验者优先2 有接口测试、自动化测试经验者优先3 国家211、985统招学历优先\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件测试\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\...
# 276  职位信息\n\n\r\n\t\t\t\t\t\t工作内容：1.负责android平台客户端应用软件开发与维护；2.按计划完成功能模块代码编写，模块测试，保证代码质量；3.持续的优化相关的产品的质量、性能。职位要求：1.一年以上android产品研发经验2、熟练掌握java语言，掌握常见的数据结构和算法，有良好的编程习惯；3、熟悉android开发技术，包括ui、网络等方面；4、熟悉android开发工具和相关开发测试工具的使用；5、熟练掌握android api，理解其体系结构、界面绘制、后台运行、数据存储等的原理，http、tcp/ip、socket等协议；6、熟悉手机终端特性，具有不同型号手机适配及移植经验；7、具备良好的职业素养和团队协作精神，以及较强的学习和交流能力。\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t手机应用开发工程师\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\...
# 277  职位信息\n\n\r\n\t\t\t\t\t\t岗位职责：1. 基于cocos2dx开发手游客户端框架；2. 作整个架构的设计，并实现相关的工具、类库；3. 提供关键问题的解决方案。 岗位要求：1.  一年以上手游开发经验；2.  精通c/c++，精通数据结构与算法，编程功底扎实；3.  有cocos2d-x游戏的开发经验，有棋牌项目经验者优先；4．熟悉eclipse、xcode、c++、java、oc等相关工具和语言；5．工作踏实认真，学习能力强，具有很强的责任心，有良好的抗压能力；\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t其他\t\t\t\t\t\t\t\t\t\n\n\n关键字：\ncocos2d-x\n开发工程师\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：香坊万达附近\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t神州通信有限公司是一家全国性网络运营商和新电信...
# 278  职位信息\n\n\n任职要求：1.扎实的java语言基础，能够熟练使用ssh或ssi等应用主流的开发框架和技术开发项目，熟练掌握jsp/servlet/ejb和javascript/ajax /jquery /html/ css等web开发技术，有vue.js或angularjs开发经验优先2. 能胜任mvc开发模式中控制层和视图层开发工作3. 熟悉大型数据库oracle,mysql或mongodb数据库, 对sql优化有较丰富的经验； 有性能优化方面的经验优先，对nosql数据库有经验者优先4. 熟悉tomcat、nginx、apache等主流web服务器5. 熟悉j2ee体系架构, 掌握面向对象的分析和设计，熟练应用java设计模式，熟悉流行的开源技术6. 了解freemarker、velocity等模板引擎,了解shiro安全框架7. 了解分布式系统的设计和应用，了解分布式、缓存、消息等机制8. 开发过软件技术平台、表单定制功能、代码生成器者优先公司待遇：五险+双休+法定假日休息+通勤车+年休假+午餐补助+员工旅游企业地址：哈尔滨市平房区松花路9号中国云谷a6栋5层\n\...
# 279  职位信息\n\n\n1、大专及以上学历，理工类专业。2、熟悉java编程语言，熟悉面向对象。3、了解安卓app开发，或有志于从事安卓开发类工作。4、有较强的逻辑思维能力、学习能力、执行能力。5、有项目开发经验者优先。 6、在校大三或大四有从事软件行业期望的学生。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t其他\t\t\t\t\t\t\t\t\t\n\n\n关键字：\nandroid\n开发\n软件\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：民生路120号万象上东\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t移创物联科技技术有限公司位于总理故乡、历史名城―――江苏淮安，由淮安政府相关投资基金、通行业资深团队共同组建。致力于通过物联网、云计算技术解决电信运营商的光网“哑”资源管理难题，为通信行业提供光交箱管理、光网资源普查和光网调度等方面的技术服务、智能锁具和专用仪器设备。移创物联拥有经验丰富的电信光网络管理及维护队伍和实力雄厚的研发能力， 可以...
# 280  职位信息\n\n\n岗位职责： 1. 帮助软件开发工程师处理日常工作。具体的工作：在软件工程师的指导下编写程序、编写过程文档、参与项目研发、学习软件开发知识和实践技巧。 2. 涉及技术：java、spring mvc、mybatis、mysql、oracle、nigix、大数据、android开发、ios开发 任职要求： 1. 本科以上学历理工科类大三或大四学生，如计算机、网络、电子信息、软件工程、（电气）自动化、测控、生仪、机电等专业，有志于在it行业发展； 2.有计算机语言基础者优先，如：c/ c++ 、java、.net等 3、有丰富的编码实战经验，热爱计算机编程优先； 4、具备优秀的分析问题和解决问题的能力，逻辑思维能力强； 5、具有良好的合作意识，执行力强，善于沟通。\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t其他\t\t\t\t\t\t\t\t\t\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：民生路120号万象上东\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r...
# 281  职位信息\n\n\n1.计算机、软件等相关专业大四在校生；2.熟练使用office系列软件，如word、excel、powerpoint；3.良好的沟通表达能力，具备团队合作意识。能承受工作压力，具备较强学习能力。4.了解java开发基本知识优先；5.学习接触过其中一种数据库（oracle、mysql），能够编写简单的sql语句优先；6.毕业后转为正式员工，签订劳动合同，缴纳五险一金，福利待遇优厚；\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t软件工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\n软件\njava\n开发\n\n\n\n微信分享\n\n\n\n\n\n\n\n联系方式\n\n\n\n上班地址：哈尔滨市南岗区天顺街21号\t\t\t\t\t\t\t\n地图\n\n\n\n\n\n公司信息\n\n\r\n\t\t\t\t\t\t哈尔滨华强电力自动化工程有限公司成立于一九九七年五月，注册资金2000万元，为中宇泰达投资有限公司的全资子公司，是集信息化产品研发、生产经营和服务为一体的高科技企业，公司人员180人，技术人员160...
# 282  职位信息\n\n\n工作职责：1、负责android手机应用软件的需求分析、功能设计、编码和测试；2、能独立进行应用程序的开发和移植，按照项目计划，按时提交高质量代码，完成开发任务。3、负责公司android平台应用的开发和维护4、配合后台和数据业务需求完成开发工作5、对android应用做出系统和数据优化任职要求：1、2年以上android客户端开发经验；2、精通android系统架构及相关技术，熟悉安卓ui框架，熟悉所有常用安卓控件；3、熟悉无线网络应用开发，精通socket和http网络接口编程, 熟悉android app客户端/服务端通讯方案；4、具有独立android客户端开发能力，熟练掌握java、设计模式、数据结构和算法；5、具有强烈的责任心和团队合作精神,喜欢创新,适应创业团队氛围；6、有主流应用软件开发经历的优先考虑；职能类别：软件工程师\n\n\n职能类别：\n\r\n\t\t\t\t\t\t\t\t\t\t手机应用开发工程师\t\t\t\t\t\t\t\t\t\n\n\n关键字：\nandroid\n手机应用\n手机端\n移动端\n\n\n\n微信分享\...
#
# [283 rows x 1 columns]

# %%
segments = []
for index, row in rows.iterrows():
    content = row[0]
    #TextRank 关键词抽取，只获取固定词性
    words = jieba.analyse.textrank(content, topK=50,withWeight=False,allowPOS=('ns', 'n', 'vn', 'v'))
    splitedStr = ''
    for word in words:
        # 记录全局分词
        segments.append({'word':word, 'count':1})
        splitedStr += word + ' '
dfSg = pd.DataFrame(segments)

# 词频统计
dfWord = dfSg.groupby('word')['count'].sum()
#导出csv
dfWord.to_csv('keywords.csv',encoding='utf-8')
